# %%
import pandas as pd

# %%
automobile_data = pd.read_csv('C:/Users/Aloine_Inc/PycharmProjects/untitled/venv/datasets/automobile.csv',
                              sep=r'\s*, \s*',
                              engine='python')

# %%
automobile_data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>"3</th>
#       <th>?</th>
#       <th>alfa-romero</th>
#       <th>gas</th>
#       <th>std</th>
#       <th>two</th>
#       <th>convertible</th>
#       <th>rwd</th>
#       <th>front</th>
#       <th>88.60</th>
#       <th>...</th>
#       <th>130</th>
#       <th>mpfi</th>
#       <th>3.47</th>
#       <th>2.68</th>
#       <th>9.00</th>
#       <th>111</th>
#       <th>5000</th>
#       <th>21</th>
#       <th>27</th>
#       <th>13495"</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>"3</td>
#       <td>?</td>
#       <td>alfa-romero</td>
#       <td>gas</td>
# ...
